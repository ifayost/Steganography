# %%
from steganography import HideOnImage, read_file_bytes, write_file_bytes
import numpy as np

# %%
import PIL
PIL.__version__
# Out:
# '8.1.2'

# %%
np.__version__
# Out:
# '1.19.5'

# %%
hideImage = HideOnImage()
image = hideImage.load_images('./')

# %%
from PIL import Image

# %%
img = Image.open('./kali-linux.jpg').convert('RGB')

# %%
w, h = img.size
pix = list(img.getdata())

# %%
Image.open('./kali-linux.jpg').mode
# Out:
# 'P'

# %%
(1080, 1920, 3)
# Out:
# (1080, 1920, 3)

# %%
img.filename
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/pi/python/Steganography/steganography.ipynb Celda 10 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Blostplace.local/home/pi/python/Steganography/steganography.ipynb#X34sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> img.filename
#
# AttributeError: 'Image' object has no attribute 'filename'

# %%
np.asarray(Image.open('./kali-linux.jpg')).shape
# Out:
# (1080, 1920)

# %%
Image.fromarray(np.asarray(img, dtype='uint8'))
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x7F8A3292B0>

# %%
np.array(Image.open('./image.jpg')).shape
# Out:
# (316, 416)

# %%
bytes2hide = read_file_bytes('./secreto.txt')

# %%
hideImage = HideOnImage()
hideImage.hide_and_save(pathRead='./', 
                        bytes2hide=bytes2hide,
                        pathWrite='./modified')

# %%
len(hideImage.bytes2hide)
# Out:
# 5438

# %%
'asdgadg'.encode()
# Out:
# b'asdgadg'

# %%
hideImage = HideOnImage()
hiddenBytes = hideImage.read_hidden_bits('./modified')

# %%
len('prueba-'*366)
# Out:
# 2562

# %%
len(hiddenBytes)
# Out:
# 2562

# %%
images = hideImage.load_images('./')

# %%
len(images[0].flatten())
# Out:
# 3275520
